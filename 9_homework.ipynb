# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats 
file_to_load = "belize_airbnb_listings.csv"
df = pd.read_csv(file_to_load)
df1 = pd.DataFrame(df)
df1
# Out:
#             id                                               name    host_id  \
# 0        36666         Mo's Cozy Casa w/ veranda & access to dock     157752
# 1        36690  Mo's Cozy Cabana w/ comfy veranda & access to ...     157752
# 2       108932  Purple House eco solar  w/ ocean & wildlife views     563377
# 3       110483                            Michelo's fuchsia suite     567809
# 4       120115               Seaside Villas Second Floor Unit  #4     604999
# ...        ...                                                ...        ...
# 2791  48283996                                     Magical Island   17994012
# 2792  48287613   The Luxury Suite - Corozal, Bz- 3Bdr/2bthr CASA1  375769845
# 2793  48296096  Lagoon front apartment w/shared pool -  two mi...   76414486
# 2794  48296978                          Beachfront Poolside Condo   15308338
# 2795  48332221           Standard Room - San Ignacio Resort Hotel   60399527
#
# ...

# %% [markdown]
#  While the Belize dataset is not normally distributed, act as if it is for the purposes of the homework.
#
# # 1. Why is assuming normal data an important consideration when answering questions about probability?

# %% [markdown]
# 1.Answer: Assuming normal distribution allows to calculate probability of different conditions using standard deviation and mean of the distribution.

# %% [markdown]
# # 2. Create two histograms in a subplot (vertical or horizontal is fine) that show the distribution of reviews_per_month and number_of_reviews in Belize Airbnb data

# %%
plt.subplot(2,2,1)

plt.hist(df1['reviews_per_month'], bins = 6)

plt.title('reviews_per_month')

plt.subplot(2,2,2)

plt.hist(df1['number_of_reviews'], bins = 6)

plt.title('number_of_reviews')
plt.show()

# %% [markdown]
# # a. How do you choose your bin size?

# %% [markdown]
# a.answer: I choose 6 bins so that bin boundaries would be placed at whole numbers

# %% [markdown]
# # 3. Create a box and whisker plot for availability_365. What does this show you?

# %% [markdown]
# 3.Answer:Box plot shows that majority of listings have high availability (200+days or above).Moreover,mean is close to the top of this box which means that a large numbers of listings are available practically all year with their 365_availability parameter approaching 365.Listings with value close to 0 are very few and are considered outliers.

# %%
df1["availability_365"].plot(kind='box',title = 'availability_365',figsize = (10,8))
plt.show()

# %% [markdown]
# # 4. What is the probability that the price for an Airbnb is under $50?

# %%
scipy.stats.norm.cdf(50,563.124825,357.102289)
# Out:
# 0.07537139614340249

# %% [markdown]
# # a. What do you notice about these records? Hint: look at the other columns.

# %%
availability_filter = df1[df1["price"] < 50]

availability_filter
# I notice that if availability_365 is close to 365, reviews per month is low and last_review_date is in 2020 or even before then - this makes sense given that this listing was unoccupied for quite some time in the last 365 days.
# Out:
#             id                                               name    host_id  \
# 134    4005831      Home away from home,  Shared dormitory, NO AC    9315171
# 148    4304743                DORMITORY Bed #1 of 6, on Maya Ruin    2084006
# 172    4936432      Home away from home,  Shared dormitory, NO AC    9315171
# 189    5509363                      Yaxche Jungle Camp, Dormitory    6960726
# 196    5717367                 Comfortable and Ecological Camping   29641332
# 315   10004488                      Long Term Stay in the country   48785884
# 341   10857678                                        Gecko Cabin   52665457
# 343   11010397                                    Tree Frog Cabin   52665457
# 344   11015225                                         Fern Cabin   52665457
# 346   11057764                                      Jacamar Cabin   52665457
# 348   11058732                                  Blue Morpho Cabin   52665457
# ...

# %% [markdown]
# # b. What distribution does this data most closely fit?
#
# b. normal distribution skewed to the left side with a cutoff at 0 value since price cannot be negative

# %%
plt.hist(df1['price'],bins=[0,100,200,300,400,500,600,700,800,900,1000])
plt.xlim(0,1000)

plt.title('price')
plt.show()

# %% [markdown]
# # 5. Calculate the sample variance and standard deviation for all the numerical columns in the same output.

# %%
latitude = df1["latitude"].agg([np.var, np.std])
longitude = df1["longitude"].agg([np.var, np.std])
price = df1["price"].agg([np.var, np.std]) 
minimum_nights = df1["minimum_nights"].agg([np.var, np.std])
number_of_reviews = df1["number_of_reviews"].agg([np.var, np.std])
#last_review = df1["last_review"].agg([np.var,np.std]) 
reviews_per_month = df1["reviews_per_month"].agg([np.var, np.std])
calculated_host_listings_count = df1["calculated_host_listings_count"].agg([np.var, np.std])
availability_365 = df1["availability_365"].agg([np.var, np.std])
df_2 = pd.DataFrame({"latitude":[latitude],"longitude":[longitude],"price":[price],"minimum_nights":[minimum_nights],"number_of_reviews":[number_of_reviews],"reviews_per_month":[reviews_per_month],"calculated_host_listings_count":[calculated_host_listings_count],"availability_365":[availability_365]})                    
df_2
# Out:
#                                             latitude  \
# 0  var    0.288841
# std    0.537440
# Name: latitude...
#
#                                            longitude  \
# 0  var    0.147361
# std    0.383876
# Name: longitud...
#
#                                                price  \
# 0  var    317109.568066
# std       563.124825
# Name...
#
#                                       minimum_nights  \
# 0  var    32.147122
# std     5.669843
# Name: minimu...
#
#                                    number_of_reviews  \
# 0  var    919.773508
# std     30.327768
# Name: numb...
#
#                                    reviews_per_month  \
# 0  var    0.438448
# std    0.662154
# Name: reviews_...
#
#                       calculated_host_listings_count  \
# 0  var    2674.046405
# std      51.711183
# Name: ca...
#
#                                     availability_365
# 0  var    14548.613157
# std      120.617632
# Name: ...

# %% [markdown]
# # a. Why sample variance and not population variance?
#
# a. Sample variance (not population variance) is being used since it is more cost-efficient.

# %% [markdown]
# # b. What is your takeaway for each metric?

# %% [markdown]
# # c. What are the scales of measurement for each of these value?

# %% [markdown]
#  Id,host_id,latitude,longitude,last_review - are " Nominal " because it is qualitative, the numbers are used here to identify the objects.
#
# price,minimum_nights,number_of_reviews, calculated_host_listings_count - are "Interval" because we can  calculating the mean and median of the variables.
#
# reviews_per_month,availability_365 - are "Ratio" because It doesn’t have negative numbers, because of its zero-point feature
# It affords unique opportunities for statistical analysis.

# %% [markdown]
# # 6. What percent of Airbnb listings in Belize are available 360 days a year or more?

# %%
availability = df1["availability_365"].count()
availability_filter = df1[df1["availability_365"] >= 360].count()
availability_1 = availability_filter/availability
availability_1["availability_365"]
# Out:
# 0.3952074391988555

# %% [markdown]
# # a. 360 days or less

# %%
availability = df1["availability_365"].count()

availability_filter = df1[df1["availability_365"] <= 360].count()

availability_1 = availability_filter/availability
availability_1["availability_365"]
# Out:
# 0.6155221745350501

# %% [markdown]
# # b. What distribution does this data most closely fit?
#
# b. This is Discrete distribution because availability_365 has a whole values.

# %%
df1["availability_365"].hist( bins=[0,50, 100,150,200,250,300,350,366])
plt.show()

# %% [markdown]
# # 7. What minimum night count are 75% of Airnbnb listing in Belize greater than?

# %%
from scipy.stats import norm

df1["minimum_nights"].agg([np.mean,np.std])
norm.ppf((1-0.75),2.263948, 5.669843)
# Out:
# -1.5603029887210025

# %%
from IPython.core.display import Image, display
display(Image('intro_stat.PNG', width=1900, unconfined=True))
